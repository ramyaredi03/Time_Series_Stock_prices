# %%
import sys
print(sys.executable)
# Out:
# C:\Users\ramya\anaconda3\envs\tsenv\python.exe

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\ramya\anaconda3\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\ramya\anaconda3\lib\site-packages (from seaborn) (2.3.5)
# Requirement already satisfied: pandas>=0.25 in c:\users\ramya\anaconda3\lib\site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\ramya\anaconda3\lib\site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ramya\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\ramya\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ramya\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ramya\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\ramya\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ramya\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\ramya\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ramya\anaconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramya\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ramya\anaconda3\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ramya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\ramya\Desktop\Time_series\Stock_prices\Datasets\BAJAJFINSV.csv")

# %%
df.head(3)
# Out:
#          Date      Symbol Series  Prev Close   Open    High    Low   Last  \
# 0  2008-05-26  BAJAJFINSV     EQ     2101.05  600.0  619.00  501.0  505.1
# 1  2008-05-27  BAJAJFINSV     EQ      509.10  505.0  610.95  491.1  564.0
# 2  2008-05-28  BAJAJFINSV     EQ      554.65  564.0  665.60  564.0  643.0
#
#     Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  509.10  548.85  3145446  1.726368e+14     NaN              908264
# 1  554.65  572.15  4349144  2.488370e+14     NaN              677627
# 2  640.95  618.37  4588759  2.837530e+14     NaN              774895
#
#    %Deliverble
# 0       0.2888
# 1       0.1558
# 2       0.1689

# %%
data=df.set_index('Date')

# %%
data.head(3)
# Out:
#                 Symbol Series  Prev Close   Open    High    Low   Last  \
# Date
# 2008-05-26  BAJAJFINSV     EQ     2101.05  600.0  619.00  501.0  505.1
# 2008-05-27  BAJAJFINSV     EQ      509.10  505.0  610.95  491.1  564.0
# 2008-05-28  BAJAJFINSV     EQ      554.65  564.0  665.60  564.0  643.0
#
#              Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2008-05-26  509.10  548.85  3145446  1.726368e+14     NaN              908264
# 2008-05-27  554.65  572.15  4349144  2.488370e+14     NaN              677627
# 2008-05-28  640.95  618.37  4588759  2.837530e+14     NaN              774895
#
#             %Deliverble
# Date
# 2008-05-26       0.2888
# 2008-05-27       0.1558
# 2008-05-28       0.1689

# %%
data.describe()
# Out:
#          Prev Close          Open          High           Low          Last  \
# count   3201.000000   3201.000000   3201.000000   3201.000000   3201.000000
# mean    2755.864386   2760.382381   2803.614449   2716.731443   2758.781537
# std     2869.811765   2874.814173   2912.885262   2834.037357   2873.792614
# min       90.750000     88.150000     93.100000     88.150000     91.000000
# 25%      527.900000    528.600000    542.600000    520.000000    527.950000
# 50%     1098.700000   1095.000000   1118.000000   1080.250000   1100.000000
# 75%     5121.900000   5120.000000   5199.800000   5042.800000   5115.000000
# max    11176.550000  11000.000000  11300.000000  10868.700000  11175.450000
#
#               Close          VWAP        Volume      Turnover         Trades  \
# count   3201.000000   3201.000000  3.201000e+03  3.201000e+03    2456.000000
# mean    2758.657451   2761.156954  2.315312e+05  9.533424e+13   20892.811075
# std     2873.522615   2874.033545  4.402681e+05  2.176448e+14   32396.302068
# min       90.750000     89.260000  4.570000e+02  1.376712e+10     149.000000
# 25%      527.900000    531.270000  3.981100e+04  2.751053e+12    2951.750000
# 50%     1098.700000   1103.560000  9.995300e+04  1.090486e+13    9450.000000
# 75%     5125.100000   5127.510000  2.315400e+05  8.755946e+13   24439.750000
# max    11176.550000  11081.780000  6.271671e+06  3.394379e+15  312959.000000
#
#        Deliverable Volume  %Deliverble
# count        3.201000e+03  3201.000000
# mean         7.409510e+04     0.471614
# std          1.464012e+05     0.218910
# min          4.560000e+02     0.056200
# 25%          2.086300e+04     0.287400
# 50%          4.159700e+04     0.469700
# 75%          8.308900e+04     0.636000
# max          3.804696e+06     1.000000

# %%
data.isna().sum()
# Out:
# Symbol                  0
# Series                  0
# Prev Close              0
# Open                    0
# High                    0
# Low                     0
# Last                    0
# Close                   0
# VWAP                    0
# Volume                  0
# Turnover                0
# Trades                745
# Deliverable Volume      0
# %Deliverble             0
# dtype: int64

# %%
data.shape
# Out:
# (3201, 14)

# %%
data['Trades'].isna().sum()
# Out:
# np.int64(745)

# %%
dataframe = data.drop(columns=['Trades'], axis=1)

# %%
dataframe.head()
# Out:
#                 Symbol Series  Prev Close    Open    High    Low   Last  \
# Date
# 2008-05-26  BAJAJFINSV     EQ     2101.05  600.00  619.00  501.0  505.1
# 2008-05-27  BAJAJFINSV     EQ      509.10  505.00  610.95  491.1  564.0
# 2008-05-28  BAJAJFINSV     EQ      554.65  564.00  665.60  564.0  643.0
# 2008-05-29  BAJAJFINSV     EQ      640.95  656.65  703.00  608.0  634.5
# 2008-05-30  BAJAJFINSV     EQ      632.40  642.40  668.00  588.3  647.0
#
#              Close    VWAP   Volume      Turnover  Deliverable Volume  \
# Date
# 2008-05-26  509.10  548.85  3145446  1.726368e+14              908264
# 2008-05-27  554.65  572.15  4349144  2.488370e+14              677627
# 2008-05-28  640.95  618.37  4588759  2.837530e+14              774895
# 2008-05-29  632.40  659.60  4522302  2.982921e+14             1006161
# 2008-05-30  644.00  636.41  3057669  1.945929e+14              462832
#
#             %Deliverble
# Date
# 2008-05-26       0.2888
# 2008-05-27       0.1558
# 2008-05-28       0.1689
# 2008-05-29       0.2225
# 2008-05-30       0.1514

# %%
dataframe.shape
# Out:
# (3201, 13)

# %%
data[dataframe.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Symbol, Series, Prev Close, Open, High, Low, Last, Close, VWAP, Volume, Turnover, Trades, Deliverable Volume, %Deliverble]
# Index: []

# %%
dataframe.dtypes
# Out:
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Deliverable Volume      int64
# %Deliverble           float64
# dtype: object

# %%
dataframe.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
data['VWAP'].plot(figsize=(8,6))
# Out:
# <Axes: xlabel='Date'>

# %%
sns.histplot(data=dataframe, x='VWAP')
# Out:
# <Axes: xlabel='VWAP', ylabel='Count'>

# %%
sns.kdeplot(data=dataframe, x='VWAP', fill=True)
# Out:
# <Axes: xlabel='VWAP', ylabel='Density'>

# %%
from scipy import stats

# %%
stats.probplot(x=dataframe['VWAP'], plot=plt)
# Out:
# ((array([-3.51908695, -3.27647555, -3.14237236, ...,  3.14237236,
#           3.27647555,  3.51908695], shape=(3201,)),
#   array([   89.26,    93.99,    94.79, ..., 10486.75, 10980.4 , 11081.78],
#         shape=(3201,))),
#  (np.float64(2583.530410402807),
#   np.float64(2761.156954076851),
#   np.float64(0.8981685068494001)))

# %%
dataframe.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
cols=['Open', 'High', 'Low', 'Last']

# %%
dataframe[cols].plot(figsize=(11,9), subplots=True)
# Out:
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>, <Axes: xlabel='Date'>], dtype=object)

# %%
dataframe.index[0:50]
# Out:
# Index(['2008-05-26', '2008-05-27', '2008-05-28', '2008-05-29', '2008-05-30',
#        '2008-06-02', '2008-06-03', '2008-06-04', '2008-06-05', '2008-06-06',
#        '2008-06-09', '2008-06-10', '2008-06-11', '2008-06-12', '2008-06-13',
#        '2008-06-16', '2008-06-17', '2008-06-18', '2008-06-19', '2008-06-20',
#        '2008-06-23', '2008-06-24', '2008-06-25', '2008-06-26', '2008-06-27',
#        '2008-06-30', '2008-07-01', '2008-07-02', '2008-07-03', '2008-07-04',
#        '2008-07-07', '2008-07-08', '2008-07-09', '2008-07-10', '2008-07-11',
#        '2008-07-14', '2008-07-15', '2008-07-16', '2008-07-17', '2008-07-18',
#        '2008-07-21', '2008-07-22', '2008-07-23', '2008-07-24', '2008-07-25',
#        '2008-07-28', '2008-07-29', '2008-07-30', '2008-07-31', '2008-08-01'],
#       dtype='object', name='Date')

# %%
import plotly.graph_objects as go

# %%
fig=go.Figure(data = [go.Candlestick(x=dataframe.index[0:50],
                                open = dataframe['Open'][0:50],
                                high = dataframe['High'][0:50],
                                low = dataframe['Low'][0:50],
                                close = dataframe['Close'][0:50])])

# %%
fig.update_layout(xaxis_rangeslider_visible=True)

# %%
dataframe['Close'][0:10]
# Out:
# Date
# 2008-05-26    509.10
# 2008-05-27    554.65
# 2008-05-28    640.95
# 2008-05-29    632.40
# 2008-05-30    644.00
# 2008-06-02    686.95
# 2008-06-03    672.05
# 2008-06-04    598.95
# 2008-06-05    631.85
# 2008-06-06    630.90
# Name: Close, dtype: float64

# %%
dataframe.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
lag_features = ['Low', 'High','Volume', 'Turnover']
window1=3
window2=7

# %%
data['High'].rolling(window=3).mean()
# Out:
# Date
# 2008-05-26             NaN
# 2008-05-27             NaN
# 2008-05-28      631.850000
# 2008-05-29      659.850000
# 2008-05-30      678.866667
#                   ...
# 2021-04-26    10059.766667
# 2021-04-27    10133.466667
# 2021-04-28    10291.316667
# 2021-04-29    10682.983333
# 2021-04-30    11046.983333
# Name: High, Length: 3201, dtype: float64

# %%
for col in lag_features:
    dataframe[col+"rolling_mean_3"]=dataframe[col].rolling(window=window1).mean()
    dataframe[col+"rolling_mean_7"]=dataframe[col].rolling(window=window2).mean()

# %%
dataframe.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Deliverable Volume',
#        '%Deliverble', 'Lowrolling_mean_3', 'Lowrolling_mean_7',
#        'Highrolling_mean_3', 'Highrolling_mean_7', 'Volumerolling_mean_3',
#        'Volumerolling_mean_7', 'Turnoverrolling_mean_3',
#        'Turnoverrolling_mean_7'],
#       dtype='object')

# %%
dataframe.head(3)
# Out:
#                 Symbol Series  Prev Close   Open    High    Low   Last  \
# Date
# 2008-05-26  BAJAJFINSV     EQ     2101.05  600.0  619.00  501.0  505.1
# 2008-05-27  BAJAJFINSV     EQ      509.10  505.0  610.95  491.1  564.0
# 2008-05-28  BAJAJFINSV     EQ      554.65  564.0  665.60  564.0  643.0
#
#              Close    VWAP   Volume  ...  Deliverable Volume  %Deliverble  \
# Date                                 ...
# 2008-05-26  509.10  548.85  3145446  ...              908264       0.2888
# 2008-05-27  554.65  572.15  4349144  ...              677627       0.1558
# 2008-05-28  640.95  618.37  4588759  ...              774895       0.1689
#
#             Lowrolling_mean_3  Lowrolling_mean_7  Highrolling_mean_3  \
# Date
# 2008-05-26                NaN                NaN                 NaN
# 2008-05-27                NaN                NaN                 NaN
# 2008-05-28              518.7                NaN              631.85
#
#             Highrolling_mean_7  Volumerolling_mean_3  Volumerolling_mean_7  \
# Date
# 2008-05-26                 NaN                   NaN                   NaN
# 2008-05-27                 NaN                   NaN                   NaN
# 2008-05-28                 NaN             4027783.0                   NaN
#
#             Turnoverrolling_mean_3  Turnoverrolling_mean_7
# Date
# 2008-05-26                     NaN                     NaN
# 2008-05-27                     NaN                     NaN
# 2008-05-28            2.350756e+14                     NaN
#
# [3 rows x 21 columns]

# %%
for col in lag_features:
    dataframe[col+"rolling_std_3"]=dataframe[col].rolling(window=window1).std()
    dataframe[col+"rolling_std_7"]=dataframe[col].rolling(window=window2).std()

# %%
dataframe.head(3)
# Out:
#                 Symbol Series  Prev Close   Open    High    Low   Last  \
# Date
# 2008-05-26  BAJAJFINSV     EQ     2101.05  600.0  619.00  501.0  505.1
# 2008-05-27  BAJAJFINSV     EQ      509.10  505.0  610.95  491.1  564.0
# 2008-05-28  BAJAJFINSV     EQ      554.65  564.0  665.60  564.0  643.0
#
#              Close    VWAP   Volume  ...  Turnoverrolling_mean_3  \
# Date                                 ...
# 2008-05-26  509.10  548.85  3145446  ...                     NaN
# 2008-05-27  554.65  572.15  4349144  ...                     NaN
# 2008-05-28  640.95  618.37  4588759  ...            2.350756e+14
#
#             Turnoverrolling_mean_7  Lowrolling_std_3  Lowrolling_std_7  \
# Date
# 2008-05-26                     NaN               NaN               NaN
# 2008-05-27                     NaN               NaN               NaN
# 2008-05-28                     NaN         39.542003               NaN
#
#             Highrolling_std_3  Highrolling_std_7  Volumerolling_std_3  \
# Date
# 2008-05-26                NaN                NaN                  NaN
# 2008-05-27                NaN                NaN                  NaN
# 2008-05-28          29.504195                NaN        773461.552524
#
#             Volumerolling_std_7  Turnoverrolling_std_3  Turnoverrolling_std_7
# Date
# 2008-05-26                  NaN                    NaN                    NaN
# 2008-05-27                  NaN                    NaN                    NaN
# 2008-05-28                  NaN           5.682195e+13                    NaN
#
# [3 rows x 29 columns]

# %%
dataframe.isna().sum()
# Out:
# Symbol                    0
# Series                    0
# Prev Close                0
# Open                      0
# High                      0
# Low                       0
# Last                      0
# Close                     0
# VWAP                      0
# Volume                    0
# Turnover                  0
# Deliverable Volume        0
# %Deliverble               0
# Lowrolling_mean_3         2
# Lowrolling_mean_7         6
# Highrolling_mean_3        2
# Highrolling_mean_7        6
# Volumerolling_mean_3      2
# Volumerolling_mean_7      6
# Turnoverrolling_mean_3    2
# Turnoverrolling_mean_7    6
# Lowrolling_std_3          2
# Lowrolling_std_7          6
# Highrolling_std_3         2
# Highrolling_std_7         6
# Volumerolling_std_3       2
# Volumerolling_std_7       6
# Turnoverrolling_std_3     2
# Turnoverrolling_std_7     6
# dtype: int64

# %%
dataframe.dropna(inplace=True)

# %%
dataframe.isna().sum()
# Out:
# Symbol                    0
# Series                    0
# Prev Close                0
# Open                      0
# High                      0
# Low                       0
# Last                      0
# Close                     0
# VWAP                      0
# Volume                    0
# Turnover                  0
# Deliverable Volume        0
# %Deliverble               0
# Lowrolling_mean_3         0
# Lowrolling_mean_7         0
# Highrolling_mean_3        0
# Highrolling_mean_7        0
# Volumerolling_mean_3      0
# Volumerolling_mean_7      0
# Turnoverrolling_mean_3    0
# Turnoverrolling_mean_7    0
# Lowrolling_std_3          0
# Lowrolling_std_7          0
# Highrolling_std_3         0
# Highrolling_std_7         0
# Volumerolling_std_3       0
# Volumerolling_std_7       0
# Turnoverrolling_std_3     0
# Turnoverrolling_std_7     0
# dtype: int64

# %%
# !pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\ramya\anaconda3\lib\site-packages (2.1.1)
# Requirement already satisfied: joblib>=0.11 in c:\users\ramya\anaconda3\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\ramya\anaconda3\lib\site-packages (from pmdarima) (3.2.2)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\ramya\anaconda3\lib\site-packages (from pmdarima) (2.3.5)
# Requirement already satisfied: pandas>=0.19 in c:\users\ramya\anaconda3\lib\site-packages (from pmdarima) (2.0.3)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\ramya\anaconda3\lib\site-packages (from pmdarima) (1.6.1)
# Requirement already satisfied: scipy>=1.13.0 in c:\users\ramya\anaconda3\lib\site-packages (from pmdarima) (1.16.3)
# Requirement already satisfied: statsmodels>=0.14.5 in c:\users\ramya\anaconda3\lib\site-packages (from pmdarima) (0.14.6)
# Requirement already satisfied: urllib3 in c:\users\ramya\anaconda3\lib\site-packages (from pmdarima) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=42 in c:\users\ramya\anaconda3\lib\site-packages (from pmdarima) (80.9.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\ramya\anaconda3\lib\site-packages (from pmdarima) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ramya\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramya\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ramya\anaconda3\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\ramya\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ramya\anaconda3\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\ramya\anaconda3\lib\site-packages (from statsmodels>=0.14.5->pmdarima) (1.0.2)

# %%
training_data=dataframe[0:2400]
testing_data=dataframe[2400:]

# %%
len(training_data)
# Out:
# 2400

# %%
dataframe.columns
# Out:
# Index(['Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Deliverable Volume',
#        '%Deliverble', 'Lowrolling_mean_3', 'Lowrolling_mean_7',
#        'Highrolling_mean_3', 'Highrolling_mean_7', 'Volumerolling_mean_3',
#        'Volumerolling_mean_7', 'Turnoverrolling_mean_3',
#        'Turnoverrolling_mean_7', 'Lowrolling_std_3', 'Lowrolling_std_7',
#        'Highrolling_std_3', 'Highrolling_std_7', 'Volumerolling_std_3',
#        'Volumerolling_std_7', 'Turnoverrolling_std_3',
#        'Turnoverrolling_std_7'],
#       dtype='object')

# %%
ind_features=['Lowrolling_mean_3', 'Lowrolling_mean_7',
       'Highrolling_mean_3', 'Highrolling_mean_7', 'Volumerolling_mean_3',
       'Volumerolling_mean_7', 'Turnoverrolling_mean_3',
       'Turnoverrolling_mean_7', 'Lowrolling_std_3', 'Lowrolling_std_7',
       'Highrolling_std_3', 'Highrolling_std_7', 'Volumerolling_std_3',
       'Volumerolling_std_7', 'Turnoverrolling_std_3',
       'Turnoverrolling_std_7']

# %%
from pmdarima import auto_arima

# %%
model=auto_arima(y=training_data['VWAP'], X=training_data[ind_features], trace=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=21501.835, Time=3.06 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=22553.316, Time=1.98 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=21962.071, Time=2.13 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=21621.885, Time=2.50 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=38832.057, Time=1.79 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=21603.220, Time=3.52 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=21569.179, Time=2.28 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=21504.415, Time=3.16 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=21496.754, Time=3.19 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=21507.716, Time=2.76 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=21498.541, Time=3.26 sec
#  ARIMA(2,0,4)(0,0,0)[0] intercept   : AIC=21493.527, Time=3.74 sec
#  ARIMA(1,0,4)(0,0,0)[0] intercept   : AIC=21504.646, Time=3.68 sec
#  ARIMA(3,0,4)(0,0,0)[0] intercept   : AIC=21484.783, Time=4.20 sec
#  ARIMA(4,0,4)(0,0,0)[0] intercept   : AIC=21489.663, Time=4.72 sec
#  ARIMA(3,0,5)(0,0,0)[0] intercept   : AIC=21490.537, Time=3.72 sec
#  ARIMA(2,0,5)(0,0,0)[0] intercept   : AIC=21488.270, Time=3.53 sec
#  ARIMA(4,0,3)(0,0,0)[0] intercept   : AIC=21488.452, Time=3.56 sec
#  ARIMA(4,0,5)(0,0,0)[0] intercept   : AIC=21494.084, Time=3.96 sec
#  ARIMA(3,0,4)(0,0,0)[0]             : AIC=21482.783, Time=3.73 sec
#  ARIMA(2,0,4)(0,0,0)[0]             : AIC=21491.524, Time=3.68 sec
#  ARIMA(3,0,3)(0,0,0)[0]             : AIC=21496.543, Time=3.76 sec
#  ARIMA(4,0,4)(0,0,0)[0]             : AIC=21487.663, Time=4.46 sec
#  ARIMA(3,0,5)(0,0,0)[0]             : AIC=21488.538, Time=3.51 sec
#  ARIMA(2,0,3)(0,0,0)[0]             : AIC=21494.755, Time=3.19 sec
#  ARIMA(2,0,5)(0,0,0)[0]             : AIC=21486.270, Time=3.65 sec
#  ARIMA(4,0,3)(0,0,0)[0]             : AIC=21486.453, Time=3.54 sec
#  ARIMA(4,0,5)(0,0,0)[0]             : AIC=21492.085, Time=3.82 sec
#
# Best model:  ARIMA(3,0,4)(0,0,0)[0]
# Total fit time: 94.160 seconds

# %%
model
# Out:
# ARIMA(order=(3, 0, 4), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
import warnings
from warnings import filterwarnings
filterwarnings("ignore")

# %%
forecast = model.predict(n_periods=len(testing_data), X=testing_data[ind_features])

# %%
forecast
# Out:
# 2400     5062.231282
# 2401     5067.144686
# 2402     5140.062334
# 2403     5181.649107
# 2404     5206.025632
#             ...
# 3190     9986.621499
# 3191    10045.040061
# 3192    10286.863488
# 3193    10784.714968
# 3194    11149.898255
# Length: 795, dtype: float64

# %%
testing_data
# Out:
#                 Symbol Series  Prev Close      Open      High       Low  \
# Date
# 2018-02-09  BAJAJFINSV     EQ     5057.25   4989.90   5088.00   4961.20
# 2018-02-12  BAJAJFINSV     EQ     5059.35   5096.30   5244.00   5042.80
# 2018-02-14  BAJAJFINSV     EQ     5235.45   5260.00   5350.00   5152.30
# 2018-02-15  BAJAJFINSV     EQ     5189.00   5200.00   5291.00   5112.05
# 2018-02-16  BAJAJFINSV     EQ     5130.35   5168.85   5199.80   5030.00
# ...                ...    ...         ...       ...       ...       ...
# 2021-04-26  BAJAJFINSV     EQ     9916.65   9992.00  10125.00   9902.20
# 2021-04-27  BAJAJFINSV     EQ    10001.75  10000.00  10133.00   9964.70
# 2021-04-28  BAJAJFINSV     EQ    10091.35  10200.00  10615.95  10151.15
# 2021-04-29  BAJAJFINSV     EQ    10489.30  10540.00  11300.00  10520.00
# 2021-04-30  BAJAJFINSV     EQ    11176.55  11000.00  11225.00  10868.70
#
#                 Last     Close      VWAP   Volume  ...  \
# Date                                               ...
# 2018-02-09   5068.00   5059.35   5037.19   144600  ...
# 2018-02-12   5210.00   5235.45   5184.22   141176  ...
# 2018-02-14   5175.00   5189.00   5272.21   154547  ...
# 2018-02-15   5134.00   5130.35   5197.04   104197  ...
# 2018-02-16   5055.55   5058.25   5089.32    88468  ...
# ...              ...       ...       ...      ...  ...
# 2021-04-26  10000.85  10001.75   9995.72   419596  ...
# 2021-04-27  10133.00  10091.35  10036.76   342847  ...
# 2021-04-28  10480.00  10489.30  10445.96  1113881  ...
# 2021-04-29  11175.45  11176.55  10980.40  1696498  ...
# 2021-04-30  11021.00  11041.65  11081.78   835355  ...
#
#             Turnoverrolling_mean_3  Turnoverrolling_mean_7  Lowrolling_std_3  \
# Date
# 2018-02-09            8.401559e+13            1.265139e+14         24.407188
# 2018-02-12            7.493284e+13            1.122500e+14         43.676538
# 2018-02-14            7.583563e+13            9.691195e+13         95.888842
# 2018-02-15            6.960694e+13            8.393934e+13         55.386333
# 2018-02-16            6.021876e+13            7.227025e+13         62.329173
# ...                            ...                     ...               ...
# 2021-04-26            5.373954e+14            5.745917e+14        146.395401
# 2021-04-27            4.629427e+14            5.423889e+14        115.977857
# 2021-04-28            6.423597e+14            6.524561e+14        129.515736
# 2021-04-29            1.123495e+15            8.239095e+14        282.598660
# 2021-04-30            1.317367e+15            8.440562e+14        358.822151
#
#             Lowrolling_std_7  Highrolling_std_3  Highrolling_std_7  \
# Date
# 2018-02-09        167.521603          61.024585          79.389987
# 2018-02-12        183.106338          78.136632         103.400785
# 2018-02-14        213.253902         131.792767         142.107292
# 2018-02-15        215.827622          53.113087         141.943483
# 2018-02-16         81.747523          75.673069         105.413408
# ...                      ...                ...                ...
# 2021-04-26        162.086761         128.351484         169.093838
# 2021-04-27        195.182734           8.709382         179.000539
# 2021-04-28        257.671610         281.169168         295.422139
# 2021-04-29        328.206090         586.380722         493.067104
# 2021-04-30        446.577142         375.164698         566.834860
#
#             Volumerolling_std_3  Volumerolling_std_7  Turnoverrolling_std_3  \
# Date
# 2018-02-09         30344.593758         91750.413573           1.452758e+13
# 2018-02-12          6967.448983         89474.878072           3.329531e+12
# 2018-02-14          6945.624834         62661.570046           4.891723e+12
# 2018-02-15         26081.131692         51372.889474           1.401207e+13
# 2018-02-16         34518.010231         36848.735971           1.897032e+13
# ...                         ...                  ...                    ...
# 2021-04-26        109533.081199        142403.920078           1.061869e+14
# 2021-04-27        147568.937973        169831.588726           1.455642e+14
# 2021-04-28        424738.252610        255574.915252           4.529369e+14
# 2021-04-29        679007.489851        471325.812668           7.601496e+14
# 2021-04-30        439428.903581        471546.294426           4.871164e+14
#
#             Turnoverrolling_std_7
# Date
# 2018-02-09           4.514870e+13
# 2018-02-12           4.375212e+13
# 2018-02-14           2.863090e+13
# 2018-02-15           2.331018e+13
# 2018-02-16           1.822208e+13
# ...                           ...
# 2021-04-26           1.363635e+14
# 2021-04-27           1.619714e+14
# 2021-04-28           2.696174e+14
# 2021-04-29           5.315495e+14
# 2021-04-30           5.324873e+14
#
# [795 rows x 29 columns]

# %%
testing_data["Forecast_ARIMA"]=forecast.values

# %%
testing_data[["Forecast_ARIMA", "VWAP"]].plot(figsize=(10,6))
# Out:
# <Axes: xlabel='Date'>

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
mean_absolute_error(testing_data['VWAP'], testing_data["Forecast_ARIMA"])
# Out:
# 76.35798269577144

# %%
mean_squared_error(testing_data['VWAP'], testing_data["Forecast_ARIMA"])
# Out:
# 11856.287739678524
